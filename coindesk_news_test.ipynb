# %% [markdown]
# ### Exact Search

# %%
# import requests
# from dotenv import load_dotenv
# import os

# load_dotenv()
# API_KEY = os.getenv("COINDESK_API")  # Make sure this is in your .env file

# if not API_KEY:
#     raise ValueError("Please set COINDESK_API in your .env file")

# response = requests.get(
#     'https://data-api.coindesk.com/news/v1/search',  # ← No trailing spaces!
#     params={
#         "search_string": "bitcoin",
#         "lang": "EN",
#         "source_key": "coindesk",
#         "api_key": API_KEY,
#         "limit": 25,
#     },
#     headers={
#         "Content-Type": "application/json; charset=UTF-8"
#     }
# )

# if response.status_code != 200:
#     print("Status Code:", response.status_code)
#     print("Response Body:", response.text)
#     response.raise_for_status()

# json_response = response.json()
# articles = json_response.get("Data", [])
# print(f"Retrieved {len(articles)} articles.")

# %%
# articles

# %% [markdown]
# ### Latest Crypto News Based on filter

# %%
import os
import requests
from dotenv import load_dotenv
from datetime import datetime
import pytz  # or use from zoneinfo import ZoneInfo if you prefer

load_dotenv()

COINDESK_API = os.getenv("COINDESK_API")

url = "https://data-api.coindesk.com/news/v1/article/list"
params = {
    "lang": "EN",
    "limit": 50,
    "sort": "published_at:desc"
}
headers = {
    "accept": "application/json",
    "x-api-key": COINDESK_API
}

response = requests.get(url, headers=headers, params=params)
response.raise_for_status()
coindesk_data = response.json()

BTC_KEYWORDS = ["bitcoin", "btc", "btc-usd", "btcusd", "btc-usdt", "btc price"]

def filter_btc_news(news_data):
    filtered = []
    for item in news_data.get("Data", []):
        combined_text = " ".join([
            item.get("TITLE", ""),
            item.get("BODY", ""),
            item.get("KEYWORDS", "")
        ]).lower()

        if any(keyword in combined_text for keyword in BTC_KEYWORDS):
            # Convert UNIX timestamp to Singapore Time
            try:
                utc_dt = datetime.utcfromtimestamp(item.get("PUBLISHED_ON", 0))
                sg_time = utc_dt.replace(tzinfo=pytz.utc).astimezone(pytz.timezone("Asia/Singapore"))
                formatted_time = sg_time.strftime("%Y-%m-%d %H:%M:%S %Z")
            except Exception:
                formatted_time = "N/A"

            filtered.append({
                "title": item.get("TITLE"),
                "url": item.get("URL"),
                "image": item.get("IMAGE_URL"),
                "published_on": formatted_time,
                "source": item.get("SOURCE_DATA", {}).get("NAME"),
                "sentiment": item.get("SENTIMENT"),
            })
    return filtered

btc_coindesk_news = filter_btc_news(coindesk_data)

btc_coindesk_news = sorted(
    btc_coindesk_news, key=lambda x: x["published_on"], reverse=True
)[:25]

# Display results
for i, n in enumerate(btc_coindesk_news, 1):
    print(f"## {i} ---> {n['published_on']} - {n['title']}")
    print(f"Source: {n['source']} | URL: {n['url']}")
    print(n)
    print()
# Out:
# ## 1 ---> 2025-10-12 04:39:31 +08 - 2025 Nobel Peace Prize Winner María Corina Machado May See Bitcoin as Resistance Money for Venezuela
# Source: CoinOtag | URL: https://en.coinotag.com/2025-nobel-peace-prize-winner-maria-corina-machado-may-see-bitcoin-as-resistance-money-for-venezuela/
# {'title': '2025 Nobel Peace Prize Winner María Corina Machado May See Bitcoin as Resistance Money for Venezuela', 'url': 'https://en.coinotag.com/2025-nobel-peace-prize-winner-maria-corina-machado-may-see-bitcoin-as-resistance-money-for-venezuela/', 'image': 'https://resources.cryptocompare.com/news/77/53005695.jpeg', 'published_on': '2025-10-12 04:39:31 +08', 'source': 'CoinOtag', 'sentiment': 'POSITIVE'}
#
# ## 2 ---> 2025-10-12 04:31:04 +08 - The Latest Nobel Peace Prize Winner Is a Bitcoin Supporter
# Source: Decrypt | URL: https://decrypt.co/343891/latest-nobel-peace-prize-winner-bitcoin-supporter
# {'title': 'The Latest Nobel Peace Prize Winner Is a Bitcoin Supporter', 'url': 'https://decrypt.co/343891/latest-nobel-peace-prize-winner-bitcoin-supporter', 'image': 'https://resources.cryptocompare.com/news/44/53005414.jpeg', 'published_on': '2025-10-12 04:31:04 +08', 'source': 'Decrypt', 'sentiment': 'POSITIVE'}
#
# ## 3 ---> 2025-10-12 04:30:13 +08 - Dogecoin Price Taps IMB Zone – What This Means And Where The Price Is Headed
# Source: NewsBTC | URL: https://www.newsbtc.com/altcoin/dogecoin-price-taps-imb-zone-what-this-means-and-where-the-price-is-headed/
# {'title': 'Dogecoin Price Taps IMB Zone – What This Means And Where The Price Is Headed', 'url': 'https://www.newsbtc.com/altcoin/dogecoin-price-taps-imb-zone-what-this-means-and-where-the-price-is-headed/', 'image': 'https://resources.cryptocompare.com/news/21/53005323.jpeg', 'published_on': '2025-10-12 04:30:13 +08', 'source': 'NewsBTC', 'sentiment': 'NEUTRAL'}
#
# ## 4 ---> 2025-10-12 04:30:04 +08 - Bitcoin and Dogecoin Lead Market Reset — MAGACOIN FINANCE Emerges as a Hidden 50x Altcoin
# Source: BitcoinSistemi | URL: https://en.bitcoinsistemi.com/bitcoin-and-dogecoin-lead-market-reset-magacoin-finance-emerges-as-a-hidden-50x-altcoin/
# {'title': 'Bitcoin and Dogecoin Lead Market Reset — MAGACOIN FINANCE Emerges as a Hidden 50x Altcoin', 'url': 'https://en.bitcoinsistemi.com/bitcoin-and-dogecoin-lead-market-reset-magacoin-finance-emerges-as-a-hidden-50x-altcoin/', 'image': 'https://resources.cryptocompare.com/news/81/53005356.jpeg', 'published_on': '2025-10-12 04:30:04 +08', 'source': 'BitcoinSistemi', 'sentiment': 'NEGATIVE'}
#
# ## 5 ---> 2025-10-12 04:21:07 +08 - Chinese Analytics Firm Founder Reveals the 4 Main Reasons Behind Yesterday’s Bitcoin and Altcoin Decline
# Source: BitcoinSistemi | URL: https://en.bitcoinsistemi.com/chinese-analytics-firm-founder-reveals-the-4-main-reasons-behind-yesterdays-bitcoin-and-altcoin-decline/
# {'title': 'Chinese Analytics Firm Founder Reveals the 4 Main Reasons Behind Yesterday’s Bitcoin and Altcoin Decline', 'url': 'https://en.bitcoinsistemi.com/chinese-analytics-firm-founder-reveals-the-4-main-reasons-behind-yesterdays-bitcoin-and-altcoin-decline/', 'image': 'https://resources.cryptocompare.com/news/81/53005088.jpeg', 'published_on': '2025-10-12 04:21:07 +08', 'source': 'BitcoinSistemi', 'sentiment': 'NEGATIVE'}
#
# ## 6 ---> 2025-10-12 04:05:29 +08 - Will bitcoin miners' pivot to AI data centers be worth the cost?
# Source: Seeking Alpha | URL: https://seekingalpha.com/news/4502387-will-bitcoin-miners-pivot-to-ai-data-centers-be-worth-the-cost?utm_source=cryptocompare.com&utm_medium=referral&feed_item_type=news
# {'title': "Will bitcoin miners' pivot to AI data centers be worth the cost?", 'url': 'https://seekingalpha.com/news/4502387-will-bitcoin-miners-pivot-to-ai-data-centers-be-worth-the-cost?utm_source=cryptocompare.com&utm_medium=referral&feed_item_type=news', 'image': 'https://resources.cryptocompare.com/news/50/53004579.jpeg', 'published_on': '2025-10-12 04:05:29 +08', 'source': 'Seeking Alpha', 'sentiment': 'NEUTRAL'}
#
# ## 7 ---> 2025-10-12 04:05:26 +08 - Expert Explains Why Recent XRP Crash Happened
# Source: TimesTabloid | URL: https://timestabloid.com/expert-explains-why-recent-xrp-crash-happened/
# {'title': 'Expert Explains Why Recent XRP Crash Happened', 'url': 'https://timestabloid.com/expert-explains-why-recent-xrp-crash-happened/', 'image': 'https://resources.cryptocompare.com/news/67/default.png', 'published_on': '2025-10-12 04:05:26 +08', 'source': 'TimesTabloid', 'sentiment': 'NEGATIVE'}
#
# ## 8 ---> 2025-10-12 04:00:50 +08 - How The Gold Rally Has Been Mirroring Bitcoin’s Momentum Over Time
# Source: Bitcoinist | URL: https://bitcoinist.com/gold-rally-mirroring-bitcoin/
# {'title': 'How The Gold Rally Has Been Mirroring Bitcoin’s Momentum Over Time', 'url': 'https://bitcoinist.com/gold-rally-mirroring-bitcoin/', 'image': 'https://resources.cryptocompare.com/news/13/53004374.jpeg', 'published_on': '2025-10-12 04:00:50 +08', 'source': 'Bitcoinist', 'sentiment': 'POSITIVE'}
#
# ## 9 ---> 2025-10-12 04:00:00 +08 - Bitcoin Price Prediction: Analyst Eyes $400K Peak, But Here’s Why Bigger Interest Is in $0.035 Mutuum Finance (MUTM)
# Source: Cryptopolitan | URL: https://www.cryptopolitan.com/analyst-eyes-400k-peak-but-heres-why-bigger-interest-is-in-0-035-mutuum-finance-mutm/
# {'title': 'Bitcoin Price Prediction: Analyst Eyes $400K Peak, But Here’s Why Bigger Interest Is in $0.035 Mutuum Finance (MUTM)', 'url': 'https://www.cryptopolitan.com/analyst-eyes-400k-peak-but-heres-why-bigger-interest-is-in-0-035-mutuum-finance-mutm/', 'image': 'https://resources.cryptocompare.com/news/43/53004696.jpeg', 'published_on': '2025-10-12 04:00:00 +08', 'source': 'Cryptopolitan', 'sentiment': 'POSITIVE'}
#
# ## 10 ---> 2025-10-12 03:47:55 +08 - Coinbase Offers Bitcoin-Centric Credit Card with Unique Features
# Source: CoinTurk News | URL: https://en.coin-turk.com/coinbase-offers-bitcoin-centric-credit-card-with-unique-features/
# {'title': 'Coinbase Offers Bitcoin-Centric Credit Card with Unique Features', 'url': 'https://en.coin-turk.com/coinbase-offers-bitcoin-centric-credit-card-with-unique-features/', 'image': 'https://resources.cryptocompare.com/news/79/53004013.jpeg', 'published_on': '2025-10-12 03:47:55 +08', 'source': 'CoinTurk News', 'sentiment': 'POSITIVE'}
#
# ## 11 ---> 2025-10-12 03:31:48 +08 - HBAR price prediction 2025-2031: Hedera Hashgraph soon to retest its ATH?
# Source: Cryptopolitan | URL: https://www.cryptopolitan.com/hbar-price-prediction/
# {'title': 'HBAR price prediction 2025-2031: Hedera Hashgraph soon to retest its ATH?', 'url': 'https://www.cryptopolitan.com/hbar-price-prediction/', 'image': 'https://resources.cryptocompare.com/news/43/3731378.jpeg', 'published_on': '2025-10-12 03:31:48 +08', 'source': 'Cryptopolitan', 'sentiment': 'POSITIVE'}
#
# ## 12 ---> 2025-10-12 03:30:00 +08 - Bitcoin Mining Stocks Plunge as $1.65 Trillion Is Wiped From US Equities
# Source: Bitcoin.com | URL: https://news.bitcoin.com/bitcoin-mining-stocks-plunge-as-1-65-trillion-is-wiped-from-us-equities/
# {'title': 'Bitcoin Mining Stocks Plunge as $1.65 Trillion Is Wiped From US Equities', 'url': 'https://news.bitcoin.com/bitcoin-mining-stocks-plunge-as-1-65-trillion-is-wiped-from-us-equities/', 'image': 'https://resources.cryptocompare.com/news/14/53003405.jpeg', 'published_on': '2025-10-12 03:30:00 +08', 'source': 'Bitcoin.com', 'sentiment': 'NEGATIVE'}
#
# ## 13 ---> 2025-10-12 03:09:17 +08 - Bitcoin, XRP, Solana Meltdown Sees Record $19 Billion In Liquidations As Trump Amps Up Tariff Showdown With China
# Source: ZyCrypto | URL: https://zycrypto.com/bitcoin-xrp-solana-meltdown-sees-record-19-billion-in-liquidations-as-trump-amps-up-tariff-showdown-with-china/
# {'title': 'Bitcoin, XRP, Solana Meltdown Sees Record $19 Billion In Liquidations As Trump Amps Up Tariff Showdown With China', 'url': 'https://zycrypto.com/bitcoin-xrp-solana-meltdown-sees-record-19-billion-in-liquidations-as-trump-amps-up-tariff-showdown-with-china/', 'image': 'https://images.cryptocompare.com/news/default/zycrypto.png', 'published_on': '2025-10-12 03:09:17 +08', 'source': 'ZyCrypto', 'sentiment': 'NEGATIVE'}
#
# ## 14 ---> 2025-10-12 03:09:02 +08 - Raoul Pal Urges Calm in the Face of Cryptocurrency Volatility
# Source: CoinTurk News | URL: https://en.coin-turk.com/raoul-pal-urges-calm-in-the-face-of-cryptocurrency-volatility/
# {'title': 'Raoul Pal Urges Calm in the Face of Cryptocurrency Volatility', 'url': 'https://en.coin-turk.com/raoul-pal-urges-calm-in-the-face-of-cryptocurrency-volatility/', 'image': 'https://resources.cryptocompare.com/news/79/53002706.jpeg', 'published_on': '2025-10-12 03:09:02 +08', 'source': 'CoinTurk News', 'sentiment': 'NEUTRAL'}
#
# ## 15 ---> 2025-10-12 03:05:28 +08 - Make No Mistake, XRP Price Tank On Binance Is Pure Manipulation
# Source: TimesTabloid | URL: https://timestabloid.com/make-no-mistake-xrp-price-tank-on-binance-is-pure-manipulation/
# {'title': 'Make No Mistake, XRP Price Tank On Binance Is Pure Manipulation', 'url': 'https://timestabloid.com/make-no-mistake-xrp-price-tank-on-binance-is-pure-manipulation/', 'image': 'https://resources.cryptocompare.com/news/67/default.png', 'published_on': '2025-10-12 03:05:28 +08', 'source': 'TimesTabloid', 'sentiment': 'NEGATIVE'}
#
# ## 16 ---> 2025-10-12 03:01:00 +08 - ‘Bitcoin Jesus’ Reaches $48M Settlement With US DOJ in Tax Fraud Case
# Source: Crypto Potato | URL: https://cryptopotato.com/bitcoin-jesus-reaches-48m-settlement-with-us-doj-in-tax-fraud-case/
# {'title': '‘Bitcoin Jesus’ Reaches $48M Settlement With US DOJ in Tax Fraud Case', 'url': 'https://cryptopotato.com/bitcoin-jesus-reaches-48m-settlement-with-us-doj-in-tax-fraud-case/', 'image': 'https://resources.cryptocompare.com/news/27/53003349.jpeg', 'published_on': '2025-10-12 03:01:00 +08', 'source': 'Crypto Potato', 'sentiment': 'NEGATIVE'}
#
# ## 17 ---> 2025-10-12 03:00:10 +08 - Bitcoin Whale Activity Reflects Sustained Confidence As $163K Comes In Sight — Details
# Source: NewsBTC | URL: https://www.newsbtc.com/news/bitcoin/bitcoin-whale-activity-reflects-sustained-confidence-as-163k-comes-in-sight-details/
# {'title': 'Bitcoin Whale Activity Reflects Sustained Confidence As $163K Comes In Sight — Details', 'url': 'https://www.newsbtc.com/news/bitcoin/bitcoin-whale-activity-reflects-sustained-confidence-as-163k-comes-in-sight-details/', 'image': 'https://resources.cryptocompare.com/news/21/53002383.jpeg', 'published_on': '2025-10-12 03:00:10 +08', 'source': 'NewsBTC', 'sentiment': 'NEUTRAL'}
#
# ## 18 ---> 2025-10-12 02:58:39 +08 - Did Trump’s Tariff Trigger A Crypto Purge Or Just A Panic?
# Source: Forbes Digital Assets | URL: https://www.forbes.com/sites/digital-assets/2025/10/11/did-trumps-tariff-trigger-a-crypto-purge-or-just-a-panic/
# {'title': 'Did Trump’s Tariff Trigger A Crypto Purge Or Just A Panic?', 'url': 'https://www.forbes.com/sites/digital-assets/2025/10/11/did-trumps-tariff-trigger-a-crypto-purge-or-just-a-panic/', 'image': 'https://resources.cryptocompare.com/news/94/53002363.jpeg', 'published_on': '2025-10-12 02:58:39 +08', 'source': 'Forbes Digital Assets', 'sentiment': 'NEGATIVE'}
#
# ## 19 ---> 2025-10-12 02:57:55 +08 - Coinbase’s Upcoming Amex Card With BTC Cashback: Everything We Know So Far
# Source: CoinDesk | URL: https://www.coindesk.com/markets/2025/10/11/coinbase-s-upcoming-amex-card-with-btc-cashback-everything-we-know-so-far
# {'title': 'Coinbase’s Upcoming Amex Card With BTC Cashback: Everything We Know So Far', 'url': 'https://www.coindesk.com/markets/2025/10/11/coinbase-s-upcoming-amex-card-with-btc-cashback-everything-we-know-so-far', 'image': 'https://resources.cryptocompare.com/news/5/53003633.jpeg', 'published_on': '2025-10-12 02:57:55 +08', 'source': 'CoinDesk', 'sentiment': 'POSITIVE'}
#
# ## 20 ---> 2025-10-12 02:39:18 +08 - Discover Real-Time Crypto Insight and Alerts with CryptoAppsy
# Source: CoinTurk News | URL: https://en.coin-turk.com/discover-real-time-crypto-insight-and-alerts-with-cryptoappsy/
# {'title': 'Discover Real-Time Crypto Insight and Alerts with CryptoAppsy', 'url': 'https://en.coin-turk.com/discover-real-time-crypto-insight-and-alerts-with-cryptoappsy/', 'image': 'https://resources.cryptocompare.com/news/79/53001756.jpeg', 'published_on': '2025-10-12 02:39:18 +08', 'source': 'CoinTurk News', 'sentiment': 'POSITIVE'}
#
# ## 21 ---> 2025-10-12 02:22:07 +08 - Claiming to Have Predicted the Drop in Cryptocurrencies, il Capo Revealed What He Expects This Weekend and Next Week
# Source: BitcoinSistemi | URL: https://en.bitcoinsistemi.com/claiming-to-have-predicted-the-drop-in-cryptocurrencies-il-capo-revealed-what-he-expects-this-weekend-and-next-week/
# {'title': 'Claiming to Have Predicted the Drop in Cryptocurrencies, il Capo Revealed What He Expects This Weekend and Next Week', 'url': 'https://en.bitcoinsistemi.com/claiming-to-have-predicted-the-drop-in-cryptocurrencies-il-capo-revealed-what-he-expects-this-weekend-and-next-week/', 'image': 'https://resources.cryptocompare.com/news/81/53001176.jpeg', 'published_on': '2025-10-12 02:22:07 +08', 'source': 'BitcoinSistemi', 'sentiment': 'NEGATIVE'}
#
# ## 22 ---> 2025-10-12 02:08:11 +08 - Crypto Market Update: Pepeto Advances Presale With Staking Rewards and Live Exchange Demo
# Source: Chainwire | URL: https://chainwire.org/2025/10/11/crypto-market-update-pepeto-advances-presale-with-staking-rewards-and-live-exchange-demo/
# {'title': 'Crypto Market Update: Pepeto Advances Presale With Staking Rewards and Live Exchange Demo', 'url': 'https://chainwire.org/2025/10/11/crypto-market-update-pepeto-advances-presale-with-staking-rewards-and-live-exchange-demo/', 'image': 'https://resources.cryptocompare.com/news/68/53000796.jpeg', 'published_on': '2025-10-12 02:08:11 +08', 'source': 'Chainwire', 'sentiment': 'POSITIVE'}
#
# ## 23 ---> 2025-10-12 02:07:40 +08 - Crypto Market Update: Pepeto Advances Presale With Staking Rewards and Live Exchange Demo
# Source: Bitcoin World | URL: https://bitcoinworld.co.in/crypto-market-update-pepeto-advances-presale-with-staking-rewards-and-live-exchange-demo/
# {'title': 'Crypto Market Update: Pepeto Advances Presale With Staking Rewards and Live Exchange Demo', 'url': 'https://bitcoinworld.co.in/crypto-market-update-pepeto-advances-presale-with-staking-rewards-and-live-exchange-demo/', 'image': 'https://resources.cryptocompare.com/news/82/53000683.jpeg', 'published_on': '2025-10-12 02:07:40 +08', 'source': 'Bitcoin World', 'sentiment': 'POSITIVE'}
#
# ## 24 ---> 2025-10-12 02:06:19 +08 - Crypto Market Update: Pepeto Advances Presale With Staking Rewards and Live Exchange Demo
# Source: Bitzo | URL: https://bitzo.com/2025/10/crypto-market-update-pepeto-advances-presale-with-staking-rewards-and-live-exchange-demo
# {'title': 'Crypto Market Update: Pepeto Advances Presale With Staking Rewards and Live Exchange Demo', 'url': 'https://bitzo.com/2025/10/crypto-market-update-pepeto-advances-presale-with-staking-rewards-and-live-exchange-demo', 'image': 'https://resources.cryptocompare.com/news/104/53000691.jpeg', 'published_on': '2025-10-12 02:06:19 +08', 'source': 'Bitzo', 'sentiment': 'POSITIVE'}
#
# ## 25 ---> 2025-10-12 02:05:54 +08 - Crypto Market Update: Pepeto Advances Presale With Staking Rewards and Live Exchange Demo
# Source: Crypto Daily | URL: https://cryptodaily.co.uk/2025/10/crypto-market-update-pepeto-advances-presale-with-staking-rewards-and-live-exchange-demo
# {'title': 'Crypto Market Update: Pepeto Advances Presale With Staking Rewards and Live Exchange Demo', 'url': 'https://cryptodaily.co.uk/2025/10/crypto-market-update-pepeto-advances-presale-with-staking-rewards-and-live-exchange-demo', 'image': 'https://resources.cryptocompare.com/news/75/53000799.jpeg', 'published_on': '2025-10-12 02:05:54 +08', 'source': 'Crypto Daily', 'sentiment': 'POSITIVE'}
# C:\Users\leeee\AppData\Local\Temp\ipykernel_40588\2982123771.py:40: DeprecationWarning: datetime.datetime.utcfromtimestamp() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.fromtimestamp(timestamp, datetime.UTC).
#   utc_dt = datetime.utcfromtimestamp(item.get("PUBLISHED_ON", 0))

# %%
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[1], line 85
#      82         await bot.close_session()
#      84 if __name__ == "__main__":
# ---> 85     asyncio.run(main())
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\asyncio\runners.py:190, in run(main, debug, loop_factory)
#     161 """Execute the coroutine and return the result.
#     162
#     163 This function runs the passed coroutine, taking care of
#    (...)    186     asyncio.run(main())
#     187 """
#     188 if events._get_running_loop() is not None:
#     189     # fail fast with short traceback
# --> 190     raise RuntimeError(
#     191         "asyncio.run() cannot be called from a running event loop")
#     193 with Runner(debug=debug, loop_factory=loop_factory) as runner:
#     194     return runner.run(main)
#
# RuntimeError: asyncio.run() cannot be called from a running event loop
