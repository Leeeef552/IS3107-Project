# %%
# import websocket
# import json
# import threading
# import time
# from datetime import datetime, timezone, timedelta
# import matplotlib.pyplot as plt
# from IPython.display import clear_output, display

# timestamps = []
# prices = []
# running = True

# def format_sgt_time(ts):
#     """Convert UNIX timestamp to Singapore Time (HH:MM:SS)."""
#     sgt = timezone(timedelta(hours=8))
#     return datetime.fromtimestamp(int(ts), tz=timezone.utc).astimezone(sgt).strftime("%H:%M:%S")

# def on_open(ws):
#     print("Connected to Bitstamp BTC/USD WebSocket")
#     ws.send(json.dumps({
#         "event": "bts:subscribe",
#         "data": {"channel": "live_trades_btcusd"}
#     }))

# def on_message(ws, message):
#     data = json.loads(message)
#     if data.get("event") == "trade":
#         trade = data["data"]
#         price = float(trade["price"])
#         t = format_sgt_time(trade["timestamp"])
#         timestamps.append(t)
#         prices.append(price)

# def on_error(ws, error):
#     print("Error:", error)

# def on_close(ws, code, msg):
#     print("Disconnected from Bitstamp WebSocket")

# def run_ws():
#     socket = "wss://ws.bitstamp.net"
#     ws = websocket.WebSocketApp(socket,
#                                 on_open=on_open,
#                                 on_message=on_message,
#                                 on_close=on_close,
#                                 on_error=on_error)
#     ws.run_forever()

# # Start the WebSocket in a background thread
# t = threading.Thread(target=run_ws)
# t.daemon = True
# t.start()

# # Live plot loop
# plt.ion()
# plt.style.use("seaborn-v0_8-whitegrid")
# fig, ax = plt.subplots(figsize=(8, 5))

# try:
#     while True:
#         if prices:
#             clear_output(wait=True)
#             ax.clear()
#             ax.plot(timestamps, prices, linewidth=2, color="#0077cc")
#             ax.set_title("💹 Live BTC/USD Price (Bitstamp)", fontsize=14, pad=12)
#             ax.set_xlabel("Time (SGT)", fontsize=10)
#             ax.set_ylabel("Price (USD)", fontsize=10)
#             ax.tick_params(axis='x', rotation=45)
#             ax.grid(True, linestyle="--", alpha=0.4)
#             ax.set_facecolor("#fafafa")
#             plt.tight_layout()
#             display(fig)
#             time.sleep(2)
# except KeyboardInterrupt:
#     running = False
#     print("Stopped chart.")
# Out:
# Running cells with '.venv (Python 3.12.4)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '"c:/Users/leeee/OneDrive - National University of Singapore/Current Sem/IS3107/Project/BT3107-Project/.venv/Scripts/python.exe" -m pip install ipykernel -U --force-reinstall'

# %%
import asyncio
import aiohttp
from datetime import datetime

class WhaleAlertBot:
    def __init__(self, min_btc=50):
        self.min_sats = int(min_btc * 100_000_000)
        self.min_btc = min_btc
        self.session = None
        self.btc_price = None
        self.api_url = "https://mempool.space/api/mempool/recent"
        self.checked_tx = set()

    async def init_session(self):
        if not self.session:
            self.session = aiohttp.ClientSession()

    async def close_session(self):
        if self.session:
            await self.session.close()

    async def get_btc_price(self):
        try:
            await self.init_session()
            async with self.session.get(
                "https://api.coingecko.com/api/v3/simple/price?ids=bitcoin&vs_currencies=usd"
            ) as resp:
                data = await resp.json()
                self.btc_price = data["bitcoin"]["usd"]
        except:
            self.btc_price = 30_000
        return self.btc_price
    
    async def price_updater(self):
        while True:
            await self.get_btc_price()
            await asyncio.sleep(5)  # every 5 minutes


    async def send_alert(self, txid, value):
        btc = value / 100_000_000
        usd = btc * (self.btc_price or 30_000)
        print("=" * 80)
        print(f"🐋  Whale transaction detected!")
        print(f"💎  {btc:,.6f} BTC (${usd:,.0f})")
        print(f"🔗  https://mempool.space/tx/{txid}")
        print("=" * 80 + "\n")

    async def monitor(self):
        print(f"🚀 Monitoring mempool.space for transactions ≥ {self.min_btc} BTC...")
        await self.get_btc_price()
        asyncio.create_task(self.price_updater())  # run in background

        while True:
            try:
                await self.init_session()
                async with self.session.get(self.api_url) as resp:
                    txs = await resp.json()

                for tx in txs:
                    txid = tx["txid"]
                    value = tx.get("value", 0)
                    if value >= self.min_sats and txid not in self.checked_tx:
                        self.checked_tx.add(txid)
                        await self.send_alert(txid, value)
                
                if len(self.checked_tx) > 5000:
                    self.checked_tx.clear()

            except Exception as e:
                print(f"⚠️ Error fetching transactions: {e}")

            await asyncio.sleep(10)  # Poll every 10 seconds

async def main():
    bot = WhaleAlertBot(min_btc=0.01)
    try:
        await bot.monitor()
    except KeyboardInterrupt:
        print("\n👋 Stopping bot...")
    finally:
        await bot.close_session()

if __name__ == "__main__":
    asyncio.run(main())
# Out:
# 🚀 Monitoring mempool.space for transactions ≥ 0.01 BTC...
# ================================================================================
# 🐋  Whale transaction detected!
# 💎  0.078876 BTC ($9,045)
# 🔗  https://mempool.space/tx/93662f0a702bd984722596154aa214dc3c3ae518b3099d470a6e5360b0f746e2
# ================================================================================
#
# ================================================================================
# 🐋  Whale transaction detected!
# 💎  0.279461 BTC ($32,048)
# 🔗  https://mempool.space/tx/2bcd731d89f5e2e8da9ea6f9b5c6ddf63fd0637b8042aa871d445e97b2967edc
# ================================================================================
#
# ================================================================================
# 🐋  Whale transaction detected!
# 💎  0.364898 BTC ($41,846)
# 🔗  https://mempool.space/tx/1efa413ba633ea70198d0273728b9096149da25638507c967d87ae9badf9f48f
# ================================================================================
#
# ================================================================================
# 🐋  Whale transaction detected!
# 💎  0.423351 BTC ($48,549)
# 🔗  https://mempool.space/tx/0307dbd80521cbffbd9d5c8b9c33907dce77c7c03af5067d3354f838885e6692
# ================================================================================
#
# ================================================================================
# 🐋  Whale transaction detected!
# 💎  2.435970 BTC ($279,355)
# 🔗  https://mempool.space/tx/57f072e84551d89cececdac0f00b248bf8bfd2961792eedacd1789f758bbd62e
# ================================================================================
#
# ================================================================================
# 🐋  Whale transaction detected!
# 💎  0.244609 BTC ($28,052)
# 🔗  https://mempool.space/tx/fc1ee84b5c6d08cdbecc488aa8c6574dcadb195239dc6eea50cc8997975d08d4
# ================================================================================
#
# ================================================================================
# 🐋  Whale transaction detected!
# 💎  0.014031 BTC ($421)
# 🔗  https://mempool.space/tx/ea672ae3a8dc7232605be31a7adce43b24bab2a09da5d135924f55df298fe3ef
# ================================================================================
#
# ================================================================================
# 🐋  Whale transaction detected!
# 💎  3.090604 BTC ($92,718)
# 🔗  https://mempool.space/tx/10e3a7f800f745303fcf740c2e11adb1c38a245c14a583e17f2a064601c259a0
# ================================================================================
#
# ================================================================================
# 🐋  Whale transaction detected!
# 💎  2.747589 BTC ($82,428)
# 🔗  https://mempool.space/tx/3b80d1b6c9dfb0ca5385a8626d7580f3d07bb1d850d8ecffa7f9ead3954ec4d1
# ================================================================================
#
# ================================================================================
# 🐋  Whale transaction detected!
# 💎  0.424778 BTC ($12,743)
# 🔗  https://mempool.space/tx/41c6ac6b07f509d955acfaa7f47e47fa737eb2c78cbef0f66fa6a19fcb44a428
# ================================================================================
#
# ================================================================================
# 🐋  Whale transaction detected!
# 💎  0
# ================================================================================
#
# ================================================================================
# 🐋  Whale transaction detected!
# 💎  0.250629 BTC ($28,747)
# 🔗  https://mempool.space/tx/b8df4c7ee234e9d66b8b7f41eed7db826806f3882dee3c154be0ac6c53cd3907
# ================================================================================
#
# ================================================================================
# 🐋  Whale transaction detected!
# 💎  0.423351 BTC ($48,559)
# 🔗  https://mempool.space/tx/69a0101cbb06f2d9310bda19034ef93e3e8617ea2b1bcc759b286ce886a3dd07
# ================================================================================
#
# ================================================================================
# 🐋  Whale transaction detected!
# 💎  0.364898 BTC ($41,854)
# 🔗  https://mempool.space/tx/3c443f1e8b6cbe0359c12c37682fb272c04f696c9f9e0ff5b5b062aee010181e
# ================================================================================
#
# ================================================================================
# 🐋  Whale transaction detected!
# 💎  3.086979 BTC ($354,080)
# 🔗  https://mempool.space/tx/c7f94ccf1366824022b653f79b5decddb518a11687132a57c3210b2226f2b636
# ================================================================================
#
# ================================================================================
# 🐋  Whale transaction detected!
# 💎  0.073103 BTC ($8,385)
# 🔗  https://mempool.space/tx/5309d4615fefd37690ee75fa7c3c931d76883b0b6bc8ba1cbd5a051d0a643c0d
# ================================================================================
#
# ================================================================================
# 🐋  Whale transaction detected!
# 💎  0.021976 BTC ($2,521)
# 🔗  https://mempool.space/tx/993c480c4d06f8ba6d8fe09f7517c8ee87ac3fc249858fa4bf8d65b14d9237de
# ================================================================================
#
# ================================================================================
# 🐋  Whale transaction detected!
# 💎  0.010867 BTC ($1,246)
# 🔗  https://mempool.space/tx/91bd18687357599453b7e54b76f58638745a5e40f51cf7b6abd7f0b2cbf1fbb0
# ================================================================================
#
# ================================================================================
# 🐋  Whale transaction detected!
# 💎  3.073899 BTC ($92,217)
# 🔗  https://mempool.space/tx/de41c66260a391c9c6c5e8682bb8cdf36ec3df323f3b768d328b85e21d1e48ee
# ================================================================================
#
# ================================================================================
# 🐋  Whale transaction detected!
# 💎  0.035982 BTC ($1,079)
# 🔗  https://mempool.space/tx/1b901859c37b33826eb69cdef54f8ffa2978cb0b80d9242f1d12b3aad6d0a285
# ================================================================================
#
# ================================================================================
# 🐋  Whale transaction detected!
# 💎  1.031464 BTC ($30,944)
# 🔗  https://mempool.space/tx/4539d5c34c1711f7c8c49e9b0c35f06cdb0048f73895d70eaf27ee387b8b2bfa
# ================================================================================
#
# ================================================================================
# 🐋  Whale transaction detected!
# 💎  0.047767 BTC ($1,433)
# 🔗  https://mempool.space/tx/e3b5acb8d0d6303348fe00d7171d4dce62e2d4b2f93baf9541192acf02da9311
# ================================================================================
#
# ================================================================================
# 🐋  Whale transaction detected!
# 💎  42.806858 BTC ($1,284,206)
# 🔗  https://mempool.space/tx/dbed47f2cfe7ce4f4563b08f6f1b123c6b5d561e60e69e318af9aa7646bdc060
# ================================================================================
#
# ================================================================================
# 🐋  Whale transaction detected!
# 💎  0.097034 BTC ($2,911)
# 🔗  https://mempool.space/tx/f9899fca5ef611e3d745243da96dd80476878f8ce20103644f1dfeef468819b6
# ================================================================================
#
# ================================================================================
# 🐋  Whale transaction detected!
# 💎  69.131043 BTC ($2,073,931)
# 🔗  https://mempool.space/tx/1e37677e6adf11f243222ff89ed735e24d25a8bb04b1ae2e9acb20c9a7aae9d2
# ================================================================================
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 85
#      82         await bot.close_session()
#      84 if __name__ == "__main__":
# ---> 85     asyncio.run(main())
#
# File ~\OneDrive - National University of Singapore\Current Sem\IS3107\Project\BT3107-Project\.venv\Lib\site-packages\nest_asyncio.py:30, in _patch_asyncio.<locals>.run(main, debug)
#      28 task = asyncio.ensure_future(main)
#      29 try:
# ---> 30     return loop.run_until_complete(task)
#      31 finally:
#      32     if not task.done():
#
# File ~\OneDrive - National University of Singapore\Current Sem\IS3107\Project\BT3107-Project\.venv\Lib\site-packages\nest_asyncio.py:92, in _patch_loop.<locals>.run_until_complete(self, future)
#      90     f._log_destroy_pending = False
#      91 while not f.done():
# ---> 92     self._run_once()
#      93     if self._stopping:
#      94         break
#
# File ~\OneDrive - National University of Singapore\Current Sem\IS3107\Project\BT3107-Project\.venv\Lib\site-packages\nest_asyncio.py:115, in _patch_loop.<locals>._run_once(self)
#     108     heappop(scheduled)
#     110 timeout = (
#     111     0 if ready or self._stopping
#     112     else min(max(
#     113         scheduled[0]._when - self.time(), 0), 86400) if scheduled
#     114     else None)
# --> 115 event_list = self._selector.select(timeout)
#     116 self._process_events(event_list)
#     118 end_time = self.time() + self._clock_resolution
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\selectors.py:323, in SelectSelector.select(self, timeout)
#     321 ready = []
#     322 try:
# --> 323     r, w, _ = self._select(self._readers, self._writers, [], timeout)
#     324 except InterruptedError:
#     325     return ready
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\selectors.py:314, in SelectSelector._select(self, r, w, _, timeout)
#     313 def _select(self, r, w, _, timeout=None):
# --> 314     r, w, x = select.select(r, w, w, timeout)
#     315     return r, w + x, []
#
# KeyboardInterrupt:
